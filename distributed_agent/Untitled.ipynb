# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('C://Users//AthenaLee//Documents//code//data//data_SA//all_wOD_2.csv', low_memory=False)

# %%
df['ENTRY_TIME'] = pd.to_datetime(df['ENTRY_TIME'],infer_datetime_format=True)
df['EXIT_TIME'] = pd.to_datetime(df['EXIT_TIME'],infer_datetime_format=True)
df['O_TIME'] = pd.to_datetime(df['O_TIME'],infer_datetime_format=True)
df['D_TIME'] = pd.to_datetime(df['D_TIME'],infer_datetime_format=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SERVICE_AREA', 'BMS_TX_BATCH', 'DIRECTION_ID',
#        'ENTRY_TIME', 'EXIT_TIME', 'STOP', 'STOP_DURATION', 'VEHICLE_ID',
#        'IDENTITY_ID', 'Gender', 'MVDIS_CATEGORY', 'MANU_YEAR', 'MANU_MONTH',
#        'VEHICLE_AGE', 'MVDIS_BRAND', 'BRAND', 'Holiday_cnt', 'WEEKDAY_CNT',
#        'TX_cnt', 'T_MILEAGE', 'O_CITY', 'O_TIME', 'O_MILEAGE', 'D_CITY',
#        'D_TIME', 'TRIP_DURATION', 'TRIP_DISTANCE', 'ENTRY_SITE', 'EXIT_SITE',
#        'NAME', 'in_location', 'out_location', 'O_COUNTRY', 'D_COUNTRY'],
#       dtype='object')

# %%
trip_df['ENTRY_TIME'] = pd.to_datetime(trip_df['ENTRY_TIME'],infer_datetime_format=True)
trip_df['EXIT_TIME'] = pd.to_datetime(trip_df['EXIT_TIME'],infer_datetime_format=True)
trip_df['O_TIME'] = pd.to_datetime(trip_df['O_TIME'],infer_datetime_format=True)
trip_df['D_TIME'] = pd.to_datetime(trip_df['D_TIME'],infer_datetime_format=True)
# Out:
# C:\Users\AthenaLee\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\AthenaLee\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\AthenaLee\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
trip_df_1 = df[(df.O_COUNTRY == "桃園市")&(df.D_COUNTRY == "台中市")]

# %%
trip_df[(trip_df.ENTRY_TIME.dt.day == 21) & (trip_df.DIRECTION_ID == "S")]
# Out:
#          Unnamed: 0 SERVICE_AREA         BMS_TX_BATCH DIRECTION_ID  \
# 186             186           泰安  1805210002305900355            S
# 377             377           泰安  1805210002305973347            S
# 385             385           泰安  1805210002305903433            S
# 389             389           泰安  1805210002305973342            S
# 478             478           泰安  1805210002305745137            S
# 518             518           泰安  1805210002305749611            S
# 1005           1005           泰安  1805210002306752988            S
# 1079           1079           泰安  1805210002306445749            S
# 1386           1386           泰安  1805210002306664198            S
# 1524           1524           泰安  1805210002306235607            S
# 1584           1584           泰安  1805210002306198151            S
# 2188           2188           泰安  1805210002306381143            S
# 2498           2498           泰安  1805210002306392447            S
# ...

# %%
# 1805210002305900355
ss = trip_df[(trip_df.BMS_TX_BATCH == 1805210002305900355)].groupby(["SERVICE_AREA", "STOP"]).size()

# %%
pd.DataFrame(ss).reset_index().SERVICE_AREA
# Out:
# 0    泰安
# 1    湖口
# Name: SERVICE_AREA, dtype: object

# %%
pd.DataFrame(trip_df_1.groupby(['SERVICE_AREA', 'STOP']).size()).reset_index()
# Out:
#    SERVICE_AREA STOP      0
# 0            中壢    P    723
# 1            中壢    T  18127
# 2            南投    P      5
# 3            南投    T     73
# 4            泰安    P   5648
# 5            泰安    T  34704
# 6            清水    P   1141
# 7            清水    T   9037
# 8            湖口    P   2518
# 9            湖口    T  21034
# 10           西湖    P   2557
# 11           西湖    T  16585
# 12           西螺    P      6
# 13           西螺    T     58
